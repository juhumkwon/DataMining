# %% [markdown]
# <a href="https://colab.research.google.com/github/juhumkwon/DataMining/blob/main/3_1_K_%ED%8F%89%EA%B7%A0(Iris_%EB%8D%B0%EC%9D%B4%ED%84%B0).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import pandas as pd

# Iris 데이터셋 로드
iris = load_iris()
X = iris.data  # 특성 데이터
y = iris.target  # 실제 레이블 (품종)

# KMeans 모델 정의 (군집 수는 3으로 설정)
kmeans = KMeans(n_clusters=3, random_state=42)

# 모델 학습
kmeans.fit(X)

# 예측된 군집 레이블
y_kmeans = kmeans.predict(X)

# 군집의 중심점
centers = kmeans.cluster_centers_

# 결과 시각화
plt.figure(figsize=(10, 6))

# 첫 번째와 두 번째 특성을 사용하여 산점도 그리기
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

# 군집 중심 표시
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.5, marker='x')

# 레이블과 축 이름 추가
plt.title('K-Means Clustering on Iris Dataset')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# 군집화 결과 출력 (군집별 샘플 수)
cluster_counts = pd.Series(y_kmeans).value_counts()
print("군집별 샘플 수:")
print(cluster_counts)
# Out:
# 군집별 샘플 수:
# 2    61
# 1    50
# 0    39
# Name: count, dtype: int64
