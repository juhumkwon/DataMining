# %% [markdown]
# <a href="https://colab.research.google.com/github/juhumkwon/DataMining/blob/main/3_4_%EA%B3%84%EC%B8%B5%EC%A0%81%EA%B5%B0%EC%A7%91%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.datasets import make_blobs

# 샘플 데이터 생성
X, _ = make_blobs(n_samples=100, centers=3, random_state=42)

# Agglomerative Hierarchical Clustering 적용
model = AgglomerativeClustering(n_clusters=3)
y_pred = model.fit_predict(X)

# 클러스터링 결과 시각화
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap='viridis')
plt.title('Agglomerative Hierarchical Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
