# %% [markdown]
# <a href="https://colab.research.google.com/github/juhumkwon/DataMining/blob/main/3_0_%EB%8D%B4%EB%93%9C%EB%A1%9C%EA%B7%B8%EB%9E%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.datasets import load_iris

# Iris 데이터셋 로드
iris = load_iris()
X = iris.data

# 계층적 군집화(병합적 방법)
Z = linkage(X, method='ward')

# 덴드로그램 그리기
plt.figure(figsize=(10, 6))
dendrogram(Z)
plt.title('Dendrogram for Iris Dataset')
plt.xlabel('Samples')
plt.ylabel('Distance')
plt.show()
